# %% [markdown]
# <a href="https://colab.research.google.com/github/pandian-ra/EVA4_Session6/blob/master/Final_Comparing_Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import random
from torch.autograd import Variable
import random
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/EVA4/Session6/test_acc_l1.txt', 'r') as filehandle:
    test_acc_l1 = json.load(filehandle)
with open('/content/drive/My Drive/EVA4/Session6/test_acc_l2.txt', 'r') as filehandle:
    test_acc_l2 = json.load(filehandle)
with open('/content/drive/My Drive/EVA4/Session6/test_acc_Without_REG.txt', 'r') as filehandle:
    test_acc_test_acc_Without_REG = json.load(filehandle)
with open('/content/drive/My Drive/EVA4/Session6/test_acc_l1&l2.txt', 'r') as filehandle:
    test_acc_l1_and_l2 = json.load(filehandle)
with open('/content/drive/My Drive/EVA4/Session6/test_losses_l1.txt', 'r') as filehandle:
    test_losses_l1 = json.load(filehandle)
with open('/content/drive/My Drive/EVA4/Session6/test_losses_l2.txt', 'r') as filehandle:
    test_losses_l2 = json.load(filehandle)
with open('/content/drive/My Drive/EVA4/Session6/test_losses_Without_REG.txt', 'r') as filehandle:
    test_losses_Without_REG = json.load(filehandle)
with open('/content/drive/My Drive/EVA4/Session6/test_losses_l1&l2.txt', 'r') as filehandle:
    test_losses_l1_and_l2 = json.load(filehandle)

# %%
plt.plot(test_acc_test_acc_Without_REG, linewidth = 4, alpha = 0.5)
plt.plot(test_acc_l1)
plt.plot(test_acc_l2)
plt.plot(test_acc_l1_and_l2)
plt.legend(["Without Regularization","L1","L2","L1&L2"])
plt.title("Comparisation of Validation Accuracy")
plt.show()

# %%
plt.plot(test_losses_Without_REG, linewidth = 4, alpha = 0.5)
plt.plot(test_losses_l1)
plt.plot(test_losses_l2)
plt.plot(test_losses_l1_and_l2)
plt.legend(["Without Regularization","L1","L2","L1&L2"])
plt.title("Comparisation of Validation Loss")
plt.show()
